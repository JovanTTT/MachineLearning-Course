# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course'

# %%
df = pd.read_csv('C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course\\Data\\penguins_size.csv')

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df['sex'].isna().value_counts()
# Out:
# sex
# False    334
# True      10
# Name: count, dtype: int64

# %%
df[df['culmen_length_mm'].isna()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
df[df['culmen_depth_mm'].isna()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
df[df['flipper_length_mm'].isna()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
df[df['body_mass_g'].isna()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
df[df['sex'].isna()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 8    Adelie  Torgersen              34.1             18.1              193.0
# 9    Adelie  Torgersen              42.0             20.2              190.0
# 10   Adelie  Torgersen              37.8             17.1              186.0
# 11   Adelie  Torgersen              37.8             17.3              180.0
# 47   Adelie      Dream              37.5             18.9              179.0
# 246  Gentoo     Biscoe              44.5             14.3              216.0
# 286  Gentoo     Biscoe              46.2             14.4              214.0
# 324  Gentoo     Biscoe              47.3             13.8              216.0
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# ...

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df = df.drop([3, 339], axis = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 342 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            342 non-null    object
#  1   island             342 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 21.4+ KB

# %%
df.isna().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  8
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df['sex'].unique()
# Out:
# array(['MALE', 'FEMALE', '.'], dtype=object)

# %%
df[df['sex'] == '.']
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 336  Gentoo  Biscoe              44.5             15.7              217.0
#
#      body_mass_g sex
# 336       4875.0   .

# %%
sns.scatterplot(data = df, x = 'body_mass_g', y = 'sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='sex'>

# %%
df[df['sex'] == 'MALE']['body_mass_g'].mean()
# Out:
# 4545.684523809524

# %%
df[df['sex'] == 'FEMALE']['body_mass_g'].mean()
# Out:
# 3862.2727272727275

# %%
df[df['species'] == 'Gentoo'].groupby('sex').describe().transpose()
# Out:
# sex                           .       FEMALE         MALE
# culmen_length_mm  count     1.0    58.000000    61.000000
#                   mean     44.5    45.563793    49.473770
#                   std       NaN     2.051247     2.720594
#                   min      44.5    40.900000    44.400000
#                   25%      44.5    43.850000    48.100000
#                   50%      44.5    45.500000    49.500000
#                   75%      44.5    46.875000    50.500000
#                   max      44.5    50.500000    59.600000
# culmen_depth_mm   count     1.0    58.000000    61.000000
#                   mean     15.7    14.237931    15.718033
#                   std       NaN     0.540249     0.741060
#                   min      15.7    13.100000    14.100000
#                   25%      15.7    13.800000    15.200000
#                   50%      15.7    14.250000    15.700000
#                   75%      15.7    14.600000    16.100000
# ...

# %%
df[df['sex'] == '.']
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 336  Gentoo  Biscoe              44.5             15.7              217.0
#
#      body_mass_g sex
# 336       4875.0   .

# %%
df.at[336, 'sex'] = 'FEMALE'

# %%
df.loc[336]
# Out:
# species              Gentoo
# island               Biscoe
# culmen_length_mm       44.5
# culmen_depth_mm        15.7
# flipper_length_mm     217.0
# body_mass_g          4875.0
# sex                  FEMALE
# Name: 336, dtype: object

# %%
sns.pairplot(data = df, hue = 'species')
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.catplot(data = df, x = 'species', y = 'culmen_length_mm', kind = 'box', col = 'sex')

# %%
df['island']
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 4      Torgersen
# 5      Torgersen
#          ...
# 338       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 334, dtype: object

# %%
pd.get_dummies(df.drop('species', axis = 1), drop_first = True)
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
#      island_Dream  island_Torgersen  sex_MALE
# 0           False              True      True
# ...

# %%
X = pd.get_dummies(df.drop('species', axis = 1), drop_first = True)

# %%
y = df['species']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
base_preds = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay

# %%
print(classification_report(y_test, base_preds))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.91      0.95      0.93        41
#    Chinstrap       0.90      0.83      0.86        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.94       101
#    macro avg       0.94      0.93      0.93       101
# weighted avg       0.94      0.94      0.94       101

# %%
ConfusionMatrixDisplay.from_estimator(model, X_test, y_test)

# %%
model.feature_importances_
# Out:
# array([0.32352044, 0.04203954, 0.54282921, 0.01325074, 0.0681854 ,
#        0.01017467, 0.        ])

# %%
X.columns
# Out:
# Index(['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
#        'body_mass_g', 'island_Dream', 'island_Torgersen', 'sex_MALE'],
#       dtype='object')

# %%
pd.DataFrame(index = X.columns, data = model.feature_importances_, columns = ['Feature Importance']).sort_values('Feature Importance')
# Out:
#                    Feature Importance
# sex_MALE                     0.000000
# island_Torgersen             0.010175
# body_mass_g                  0.013251
# culmen_depth_mm              0.042040
# island_Dream                 0.068185
# culmen_length_mm             0.323520
# flipper_length_mm            0.542829

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize = (12, 8), dpi = 200)
plot_tree(decision_tree = model, feature_names = X.columns, filled = True); 
# X[2] --> 2 represents index of the column, in my case it is 3rd column, flipper, thats why
# flipper has the biggest importance in the dataframe above (feature_names = X.columns fixes this)
# value = [105, 5, 83] --> 105 values of one species, 5 values of another species and 83 from third one

# %%
len(X_train) # All training samples are entering root node
# Out:
# 233

# %%
def report_model(model):
    model_preds = model.predict(X_test)
    print(classification_report(y_test, model_preds))
    print('\n')
    plt.figure(figsize = (12, 8), dpi = 200)
    plot_tree(decision_tree = model, feature_names = X.columns, filled = True);

# %%
report_model(model)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.91      0.95      0.93        41
#    Chinstrap       0.90      0.83      0.86        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.94       101
#    macro avg       0.94      0.93      0.93       101
# weighted avg       0.94      0.94      0.94       101

# %%
pruned_tree = DecisionTreeClassifier(max_depth = 3)

# %%
pruned_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.95      0.96        41
#    Chinstrap       0.92      0.96      0.94        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.96      0.97      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %%
max_leaf_tree = DecisionTreeClassifier(max_leaf_nodes = 3)

# %%
max_leaf_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=3)

# %%
report_model(max_leaf_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.88      0.92        41
#    Chinstrap       0.83      0.87      0.85        23
#       Gentoo       0.93      1.00      0.96        37
#
#     accuracy                           0.92       101
#    macro avg       0.91      0.92      0.91       101
# weighted avg       0.92      0.92      0.92       101

# %%
entropy_tree = DecisionTreeClassifier(criterion = 'entropy')

# %%
entropy_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
entropy_tree.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
report_model(entropy_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.98      1.00      0.99        41
#    Chinstrap       1.00      0.96      0.98        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.99       101
#    macro avg       0.99      0.99      0.99       101
# weighted avg       0.99      0.99      0.99       101

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'splitter' : ['best', 'random'],
              'max_depth' : [None, 1, 2, 3, 4, 5],
              'criterion' : ['entropy', 'gini', 'log_loss']}

# %%
base_tree = DecisionTreeClassifier()

# %%
grid_model = GridSearchCV(estimator = base_tree, param_grid = param_grid)

# %%
grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['entropy', 'gini', 'log_loss'],
#                          'max_depth': [None, 1, 2, 3, 4, 5],
#                          'splitter': ['best', 'random']})

# %%
grid_model.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': None, 'splitter': 'best'}

# %%
y_pred = grid_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.95      1.00      0.98        41
#    Chinstrap       1.00      0.91      0.95        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.98       101
#    macro avg       0.98      0.97      0.98       101
# weighted avg       0.98      0.98      0.98       101

# %%
proba = DecisionTreeClassifier(criterion = 'entropy')

# %%
proba.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
proba_pred = proba.predict(X_test)

# %%
print(classification_report(y_test, proba_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.91      0.95      0.93        41
#    Chinstrap       0.90      0.83      0.86        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.94       101
#    macro avg       0.94      0.93      0.93       101
# weighted avg       0.94      0.94      0.94       101

# %%
entropy_preds = entropy_tree.predict(X_test)

# %%
print(classification_report(y_test, entropy_preds))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.98      1.00      0.99        41
#    Chinstrap       1.00      0.96      0.98        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.99       101
#    macro avg       0.99      0.99      0.99       101
# weighted avg       0.99      0.99      0.99       101

# %%
en = DecisionTreeClassifier(criterion = 'entropy', random_state = 42)

# %%
en.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
en_preds = en.predict(X_test)

# %%
print(classification_report(y_test, en_preds))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.93      1.00      0.96        41
#    Chinstrap       1.00      0.87      0.93        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.98      0.96      0.96       101
# weighted avg       0.97      0.97      0.97       101

# %%
en2 = DecisionTreeClassifier(criterion = 'entropy', random_state = 42)

# %%
en2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
en2_preds = en2.predict(X_test)

# %%
print(classification_report(y_test, en2_preds))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.93      1.00      0.96        41
#    Chinstrap       1.00      0.87      0.93        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.98      0.96      0.96       101
# weighted avg       0.97      0.97      0.97       101

# %%
en3 = DecisionTreeClassifier(criterion = 'entropy', random_state = 101)

# %%
en3.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=101)

# %%
en3_preds = en3.predict(X_test)

# %%
print(classification_report(y_test, en3_preds))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.95      0.98      0.96        41
#    Chinstrap       0.95      0.91      0.93        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.97      0.96      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %%
entropy_tree.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
grid_model.get_params()
# Out:
# {'cv': None,
#  'error_score': nan,
#  'estimator__ccp_alpha': 0.0,
#  'estimator__class_weight': None,
#  'estimator__criterion': 'gini',
#  'estimator__max_depth': None,
#  'estimator__max_features': None,
#  'estimator__max_leaf_nodes': None,
#  'estimator__min_impurity_decrease': 0.0,
#  'estimator__min_samples_leaf': 1,
#  'estimator__min_samples_split': 2,
#  'estimator__min_weight_fraction_leaf': 0.0,
#  'estimator__random_state': None,
#  'estimator__splitter': 'best',
#  'estimator': DecisionTreeClassifier(),
#  'n_jobs': None,
#  'param_grid': {'splitter': ['best', 'random'],
#   'max_depth': [None, 1, 2, 3, 4, 5],
#   'criterion': ['entropy', 'gini', 'log_loss']},
#  'pre_dispatch': '2*n_jobs',
#  'refit': True,
#  'return_train_score': False,
#  'scoring': None,
#  'verbose': 0}

# %%
print(classification_report(y_test, entropy_preds))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.98      1.00      0.99        41
#    Chinstrap       1.00      0.96      0.98        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.99       101
#    macro avg       0.99      0.99      0.99       101
# weighted avg       0.99      0.99      0.99       101

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.95      1.00      0.98        41
#    Chinstrap       1.00      0.91      0.95        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.98       101
#    macro avg       0.98      0.97      0.98       101
# weighted avg       0.98      0.98      0.98       101

# %%
ConfusionMatrixDisplay.from_estimator(grid_model, X_test, y_test)

# %%
ConfusionMatrixDisplay.from_estimator(entropy_tree, X_test, y_test)
