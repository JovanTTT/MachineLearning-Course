# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course'

# %%
df = pd.read_csv('C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course\\Data\\Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df['total_spend'] = df['TV'] + df['radio'] + df['newspaper']

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales  total_spend
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3    9.3        132.4
# 3  151.5   41.3       58.5   18.5        251.3
# 4  180.8   10.8       58.4   12.9        250.0

# %%
sns.regplot(data = df, x = 'total_spend', y = 'sales')
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
X = df['total_spend']
y = df['sales']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_spend'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 X = df['total_spend']
#       2 y = df['sales']
#
# ...

# %%
# y = mx + b
# y = B1x + B0
# help(np.polyfit)

# %%
np.polyfit(X, y, deg = 1)
# First num is B1, second is B0 below
# Out:
# array([0.04868788, 4.24302822])

# %%
potential_spend = np.linspace(0, 500, 100)

# %%
predicted_sales = 0.04868788 * potential_spend + 4.24302822

# %%
sns.scatterplot(x = 'total_spend', y = 'sales', data = df)
plt.plot(potential_spend, predicted_sales, color = 'red')

# %%
spend = 200

predicted_sales = 0.04868788 * spend + 4.24302822

# %%
predicted_sales
# Out:
# 13.98060422

# %%
np.polyfit(X, y, 3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
# y = B1x + Bo    (deg = 1)

# y = B3x**3 + B2x**2 + B1x + B0    (deg = 3)

# %%
potential_spend = np.linspace(0, 500, 100)

# %%
predicted_sales = 3.07615033e-07*potential_spend**3 + -1.89392449e-04*potential_spend**2 + 8.20886302e-02*potential_spend + 2.70495053e+00

# %%
predicted_sales
# Out:
# array([ 2.70495053,  3.11474825,  3.51512186,  3.90630911,  4.28854779,
#         4.66207567,  5.02713053,  5.38395013,  5.73277224,  6.07383466,
#         6.40737513,  6.73363145,  7.05284138,  7.3652427 ,  7.67107318,
#         7.97057059,  8.2639727 ,  8.5515173 ,  8.83344215,  9.10998503,
#         9.38138371,  9.64787596,  9.90969955, 10.16709227, 10.42029188,
#        10.66953616, 10.91506288, 11.15710981, 11.39591473, 11.63171541,
#        11.86474963, 12.09525515, 12.32346975, 12.54963121, 12.77397729,
#        12.99674578, 13.21817443, 13.43850104, 13.65796337, 13.87679919,
#        14.09524628, 14.31354241, 14.53192536, 14.75063289, 14.96990278,
#        15.18997281, 15.41108075, 15.63346437, 15.85736144, 16.08300974,
#        16.31064705, 16.54051112, 16.77283975, 17.0078707 , 17.24584174,
#        17.48699065, 17.73155521, 17.97977318, 18.23188233, 18.48812045,
#        18.74872531, 19.01393467, 19.28398632, 19.55911802, 19.83956755,
# ...

# %%
sns.scatterplot(data = df, x = 'total_spend', y = 'sales')
plt.plot(potential_spend, predicted_sales, color = 'red')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales  total_spend
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3    9.3        132.4
# 3  151.5   41.3       58.5   18.5        251.3
# 4  180.8   10.8       58.4   12.9        250.0

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (16, 6))

axes[0].plot(df['TV'], df['sales'], 'o')
axes[0].set_title('TV Spend')
axes[0].set_ylabel('Sales')

axes[1].plot(df['radio'], df['sales'], 'o')
axes[1].set_title('Radio Spend')
axes[1].set_ylabel('Sales')

axes[2].plot(df['newspaper'], df['sales'], 'o')
axes[2].set_title('Newspaper Spend')
axes[2].set_ylabel('Sales')

plt.tight_layout()

# %%
df = df.drop('total_spend', axis = 1)

# %%
sns.pairplot(data = df)
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
X = df.drop('sales', axis = 1)

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = df['sales']

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
# help(train_test_split)

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
#test_size = what percentage goes for testing

# %%
len(df)
# Out:
# 200

# %%
X_train
# Out:
#         TV  radio  newspaper
# 85   193.2   18.4       65.7
# 183  287.6   43.0       71.8
# 127   80.2    0.0        9.2
# 53   182.6   46.2       58.7
# 100  222.4    4.3       49.8
# ..     ...    ...        ...
# 63   102.7   29.6        8.4
# 70   199.1   30.6       38.7
# 81   239.8    4.1       36.9
# 11   214.7   24.0        4.0
# 95   163.3   31.6       52.9
#
# [140 rows x 3 columns]

# %%
y_train
# Out:
# 85     15.2
# 183    26.2
# 127     8.8
# 53     21.2
# 100    11.7
#        ...
# 63     14.0
# 70     18.3
# 81     12.3
# 11     17.4
# 95     16.9
# Name: sales, Length: 140, dtype: float64

# %%
len(X_test)
# Out:
# 60

# %%
from sklearn.linear_model import LinearRegression

# %%
# help(LinearRegression)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_predictions = model.predict(X_test)

# %%
 X_test.head()
# Out:
#         TV  radio  newspaper
# 37    74.7   49.4       45.7
# 109  255.4   26.9        5.5
# 31   112.9   17.4       38.6
# 89   109.8   47.8       51.4
# 66    31.5   24.6        2.2

# %%
y_test.head()
# Out:
# 37     14.7
# 109    19.8
# 31     11.9
# 89     16.7
# 66      9.5
# Name: sales, dtype: float64

# %%
test_predictions
# Out:
# array([15.74131332, 19.61062568, 11.44888935, 17.00819787,  9.17285676,
#         7.01248287, 20.28992463, 17.29953992,  9.77584467, 19.22194224,
#        12.40503154, 13.89234998, 13.72541098, 21.28794031, 18.42456638,
#         9.98198406, 15.55228966,  7.68913693,  7.55614992, 20.40311209,
#         7.79215204, 18.24214098, 24.68631904, 22.82199068,  7.97962085,
#        12.65207264, 21.46925937,  8.05228573, 12.42315981, 12.50719678,
#        10.77757812, 19.24460093, 10.070269  ,  6.70779999, 17.31492147,
#         7.76764327,  9.25393336,  8.27834697, 10.58105585, 10.63591128,
#        13.01002595,  9.77192057, 10.21469861,  8.04572042, 11.5671075 ,
#        10.08368001,  8.99806574, 16.25388914, 13.23942315, 20.81493419,
#        12.49727439, 13.96615898, 17.56285075, 11.14537013, 12.56261468,
#         5.50870279, 23.29465134, 12.62409688, 18.77399978, 15.18785675])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# df['sales'].mean()

# %%
sns.histplot(data = df, x = 'sales', bins = 20);
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
mean_absolute_error(y_test, test_predictions)
# Out:
# 1.213745773614481

# %%
#RMSE
np.sqrt(mean_squared_error(y_test, test_predictions))
#If it is very big value, it means that some value points are way off
# Out:
# 1.5161519375993884

# %%
test_residuals = y_test - test_predictions

# %%
test_residuals
# Out:
# 37    -1.041313
# 109    0.189374
# 31     0.451111
# 89    -0.308198
# 66     0.327143
# 119   -0.412483
# 54    -0.089925
# 74    -0.299540
# 145    0.524155
# 142    0.878058
# 148   -1.505032
# 112    0.207650
# 174   -2.225411
# 55     2.412060
# 141    0.775434
# 149    0.118016
# 25    -3.552290
# 34     1.810863
# 170    0.843850
# 39     1.096888
# 172   -0.192152
# 153    0.757859
# 175    2.313681
# 61     1.378009
# 65     1.320379
# 50    -1.252073
# 42    -0.769259
# 129    1.647714
# 179    0.176840
# 2     -3.207197
# 12    -1.577578
# 133    0.355399
# 90     1.129731
# 22    -1.107800
# 41    -0.214921
# 32     1.832357
# 125    1.346067
# 196    1.421653
# 158   -3.281056
# 180   -0.135911
# 16    -0.510026
# 186    0.528079
# 144    1.185301
# 121   -1.045720
# 80     0.232893
# 18     1.216320
# 78    -3.698066
# 48    -1.453889
# 4     -0.339423
# 15     1.585066
# 1     -2.097274
# 43    -1.066159
# 102   -2.762851
# 164    0.754630
# 9     -1.962615
# ...

# %%
sns.scatterplot(x = y_test, y = test_residuals)
plt.axhline(y = 0, color = 'red', ls = '--')

# %%
sns.displot(test_residuals, bins = 25, kde = True)
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import scipy as sp

# %%
fig, ax = plt.subplots(figsize = (6, 8), dpi = 100)
_ = sp.stats.probplot(test_residuals, plot = ax)

# %%
final_model = LinearRegression()

# %%
final_model.fit(X, y)
# Out:
# LinearRegression()

# %%
final_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
X.head() #first koef is for TV, second is for radio and third is for newspaper
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
# On example, let's look at first coeficient. It represents TV. If i increase
# one field for 1 unit, sales will go up for 0.04576465

# %%
y_hat = final_model.predict(X)

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (16, 6))

axes[0].plot(df['TV'], df['sales'], 'o')
axes[0].plot(df['TV'], y_hat, 'o', color = 'red')
axes[0].set_ylabel('Sales')
axes[0].set_title('TV Spend')

axes[1].plot(df['radio'], df['sales'], 'o')
axes[1].plot(df['radio'], y_hat, 'o', color = 'red')
axes[1].set_ylabel('Sales')
axes[1].set_title('Radio Spend')

axes[2].plot(df['newspaper'], df['sales'], 'o')
axes[2].plot(df['newspaper'], y_hat, 'o', color = 'red')
axes[2].set_ylabel('Sales')
axes[2].set_title('Newspaper spend')
# Out:
# Text(0.5, 1.0, 'Newspaper spend')

# %%
from joblib import dump, load

# %%
dump(final_model, 'final_sales_model.joblib') #saving model
# Out:
# ['final_sales_model.joblib']

# %%
loaded_model = load('final_sales_model.joblib') #loading model

# %%
loaded_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
X.shape
# Out:
# (200, 3)

# %%
#149 TV, 22 Radio, 12 Newspaper
#Sales?
campaign = [[149, 22, 12]]

# %%
loaded_model.predict(campaign)
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13.893032])

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X = df.drop('sales', axis = 1)

# %%
y = df['sales']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_converter = PolynomialFeatures(degree = 2, include_bias = False)

# %%
polynomial_converter.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_features = polynomial_converter.transform(X)

# %%
polynomial_converter.transform(X).shape
# Out:
# (200, 9)

# %%
X.shape
# Out:
# (200, 3)

# %%
X.iloc[0]
# Out:
# TV           230.1
# radio         37.8
# newspaper     69.2
# Name: 0, dtype: float64

# %%
poly_features.shape
# Out:
# (200, 9)

# %%
poly_features[0] #all combinations , A, B, C, A*A, B*B, C*C, A*B, A*C, B*C
# Out:
# array([2.301000e+02, 3.780000e+01, 6.920000e+01, 5.294601e+04,
#        8.697780e+03, 1.592292e+04, 1.428840e+03, 2.615760e+03,
#        4.788640e+03])

# %%
230.1 * 37.8
# Out:
# 8697.779999999999

# %%
polynomial_converter.fit_transform(X)
# Out:
# array([[ 230.1 ,   37.8 ,   69.2 , ..., 1428.84, 2615.76, 4788.64],
#        [  44.5 ,   39.3 ,   45.1 , ..., 1544.49, 1772.43, 2034.01],
#        [  17.2 ,   45.9 ,   69.3 , ..., 2106.81, 3180.87, 4802.49],
#        ...,
#        [ 177.  ,    9.3 ,    6.4 , ...,   86.49,   59.52,   40.96],
#        [ 283.6 ,   42.  ,   66.2 , ..., 1764.  , 2780.4 , 4382.44],
#        [ 232.1 ,    8.6 ,    8.7 , ...,   73.96,   74.82,   75.69]])

# %%
 polynomial_converter.fit_transform(X).shape
# Out:
# (200, 9)

# %%
poly_features
# Out:
# array([[ 230.1 ,   37.8 ,   69.2 , ..., 1428.84, 2615.76, 4788.64],
#        [  44.5 ,   39.3 ,   45.1 , ..., 1544.49, 1772.43, 2034.01],
#        [  17.2 ,   45.9 ,   69.3 , ..., 2106.81, 3180.87, 4802.49],
#        ...,
#        [ 177.  ,    9.3 ,    6.4 , ...,   86.49,   59.52,   40.96],
#        [ 283.6 ,   42.  ,   66.2 , ..., 1764.  , 2780.4 , 4382.44],
#        [ 232.1 ,    8.6 ,    8.7 , ...,   73.96,   74.82,   75.69]])

# %%
poly_features.shape
# Out:
# (200, 9)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_predictions = model.predict(X_test)

# %%
model.coef_
# Out:
# array([ 5.17095811e-02,  1.30848864e-02,  1.20000085e-02, -1.10892474e-04,
#         1.14212673e-03, -5.24100082e-05,  3.34919737e-05,  1.46380310e-04,
#        -3.04715806e-05])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE = mean_absolute_error(y_test, test_predictions)

# %%
MSE = mean_squared_error(y_test, test_predictions)

# %%
RMSE = np.sqrt(MSE)

# %%
MAE
# Out:
# 0.4896798044803556

# %%
RMSE
# Out:
# 0.6646431757269032

# %%
# If I train model on the same data, i can compare it to the linear regression

# %%
model.coef_
# Out:
# array([ 5.17095811e-02,  1.30848864e-02,  1.20000085e-02, -1.10892474e-04,
#         1.14212673e-03, -5.24100082e-05,  3.34919737e-05,  1.46380310e-04,
#        -3.04715806e-05])

# %%
poly_features[0]
# Out:
# array([2.301000e+02, 3.780000e+01, 6.920000e+01, 5.294601e+04,
#        8.697780e+03, 1.592292e+04, 1.428840e+03, 2.615760e+03,
#        4.788640e+03])

# %%
X.iloc[0]
# Out:
# TV           230.1
# radio         37.8
# newspaper     69.2
# Name: 0, dtype: float64

# %%
69.2**2
# Out:
# 4788.64

# %%
from sklearn.model_selection import train_test_split

# %%
poly_features.shape
# Out:
# (200, 9)

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model  = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_predictions = model.predict(X_test)

# %%
model.coef_
# Out:
# array([ 5.17095811e-02,  1.30848864e-02,  1.20000085e-02, -1.10892474e-04,
#         1.14212673e-03, -5.24100082e-05,  3.34919737e-05,  1.46380310e-04,
#        -3.04715806e-05])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE = mean_absolute_error(y_test, test_predictions)

# %%
MSE = mean_squared_error(y_test, test_predictions)

# %%
RMSE = np.sqrt(MSE)

# %%
MAE
# Out:
# 0.4896798044803556

# %%
RMSE
# Out:
# 0.6646431757269032

# %%
# 1. create the different order poly
# 2. split poly feat train/test
# 3. fit on train
# 4. store/save the rmse for BOTH the train AND test
# 5. PLOT the results (error vs poly order)

# %%
train_rmse_errors = []
test_rmse_errors = []

for d in range(1, 10):  
    
    poly_converter = PolynomialFeatures(degree = d, include_bias = False)
    poly_features = poly_converter.fit_transform(X)
    
    X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.30, random_state=101)
    
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)
    
    train_rmse = np.sqrt(mean_squared_error(y_train, train_pred))
    test_rmse = np.sqrt(mean_squared_error(y_test, test_pred))
    
    train_rmse_errors.append(train_rmse)
    test_rmse_errors.append(test_rmse)

# %%
train_rmse_errors
# Out:
# [1.734594124329376,
#  0.5879574085292231,
#  0.4339344356902068,
#  0.3517083688399348,
#  0.2509342962728227,
#  0.1994556133865361,
#  5.418481285535737,
#  0.1508621033579802,
#  0.17175170448632276]

# %%
test_rmse_errors
# Out:
# [1.516151937599388,
#  0.6646431757269032,
#  0.5803286825237266,
#  0.5077742656422755,
#  2.575808121294812,
#  4.263812349320766,
#  1383.4052620420694,
#  3733.4225752445113,
#  95489.26452707677]

# %%
plt.plot(range(1, 10), train_rmse_errors, label = 'TRAIN RMSE')
plt.plot(range(1, 10), test_rmse_errors, label = 'TEST RMSE')

plt.xlabel('Degree of Poly')
plt.ylabel('RMSE')
plt.legend()

# %%
plt.plot(range(1, 6), train_rmse_errors[:5], label = 'TRAIN RMSE')
plt.plot(range(1, 6), test_rmse_errors[:5], label = 'TEST RMSE')

plt.xlabel('Degree of Poly')
plt.ylabel('RMSE')
plt.legend()

# %%
#Degrees between 2 and 3 are optimal, when degree is 4, there is a chance to explode

# %%
final_poly_converter = PolynomialFeatures(degree = 3, include_bias = False)

# %%
final_model = LinearRegression()

# %%
full_converted_X = final_poly_converter.fit_transform(X)
final_model.fit(full_converted_X, y)
# Out:
# LinearRegression()

# %%
from joblib import dump, load

# %%
pwd
# Out:
# 'C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course'

# %%
dump(final_model, 'C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course\\Models\\final_poly_model.joblib')
# Out:
# ['C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course\\Models\\final_poly_model.joblib']

# %%
dump(final_poly_converter, 'C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course\\Models\\final_converter.joblib')
# Out:
# ['C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course\\Models\\final_converter.joblib']

# %%
loaded_converter = load('C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course\\Models\\final_converter.joblib')

# %%
loaded_model = load('C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course\\Models\\final_poly_model.joblib')

# %%
campaign = [[124, 22, 12]]

# %%
# Our model expects 19 values, because we created model with 3rd degree
# Because of that, we have converter

# %%
transformed_data = loaded_converter.fit_transform(campaign)

# %%
loaded_converter.fit_transform(campaign).shape
# Out:
# (1, 19)

# %%
loaded_model.predict(transformed_data)
# Out:
# array([13.74973272])

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train[0]
# Out:
# array([ 4.93001715e-01, -3.39942376e-01,  1.61586707e+00,  2.84073630e-01,
#        -2.56877571e-02,  1.49677566e+00, -5.90231605e-01,  4.16591545e-01,
#         1.61378530e+00,  8.05717198e-02, -5.39222900e-02,  1.01524393e+00,
#        -3.69861628e-01,  5.24579673e-01,  1.48737034e+00, -6.60960221e-01,
#        -1.63602417e-01,  5.46947535e-01,  1.37075536e+00, -8.08366010e-02,
#        -1.31261736e-01,  6.17553969e-01, -3.22725271e-01,  3.33051083e-01,
#         1.01460247e+00, -4.96157891e-01, -3.72311639e-02,  5.94671198e-01,
#         1.21049620e+00, -6.50525631e-01, -3.96375447e-01, -2.25342384e-02,
#         4.89213849e-01,  1.04610020e+00, -1.96271073e-01, -2.01612583e-01,
#         3.22049694e-01, -3.19033638e-01,  1.53254169e-01,  6.29357548e-01,
#        -4.30186860e-01, -7.29037792e-02,  3.72777218e-01,  8.00504129e-01,
#        -5.20107901e-01, -2.90373098e-01,  6.58729401e-02,  4.97487714e-01,
# ...

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha = 10)

# %%
ridge_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=10)

# %%
test_predictions = ridge_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE = mean_absolute_error(y_test, test_predictions)

# %%
MAE
# Out:
# 0.6249915635783218

# %%
RMSE = np.sqrt(mean_squared_error(y_test, test_predictions))

# %%
RMSE
# Out:
# 0.9256089802403035

# %%
from sklearn.linear_model import RidgeCV # CV = Cross Validation

# %%
ridge_cv_model = RidgeCV(alphas = (0.1, 1.0, 10.0), scoring = 'neg_mean_absolute_percentage_error')

# %%
ridge_cv_model.fit(X_train, y_train)
# Out:
# RidgeCV(scoring='neg_mean_absolute_percentage_error')

# %%
ridge_cv_model.alpha_ # The best performing alpha
# Out:
# 1.0

# %%
from sklearn.metrics import SCORERS

# %%
SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'matthews_corrcoef', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'top_k_accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'positive_likelihood_ratio', 'neg_negative_likelihood_ratio', 'adjusted_rand_score', 'rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_we
# ...

# %%
test_predictions = ridge_cv_model.predict(X_test)

# %%
MAE = mean_absolute_error(y_test, test_predictions)

# %%
RMSE = np.sqrt(mean_squared_error(y_test, test_predictions))

# %%
MAE
# Out:
# 0.5953100575021106

# %%
RMSE
# Out:
# 0.9242857053351105

# %%
ridge_cv_model.coef_
# Out:
# array([ 3.24417964e+00,  7.81879078e-01,  1.58464053e-01, -5.68885604e-01,
#         2.43388762e+00,  2.73918332e-01, -3.50221690e-01,  3.29459798e-01,
#        -1.98987907e-01, -8.12622390e-01,  9.64428148e-02, -4.99385074e-01,
#         1.34998229e+00,  2.24908940e-01, -1.47548474e-03, -5.65396163e-01,
#         9.18740228e-02, -1.05326902e-01,  1.47965270e-02, -4.63297286e-01,
#        -7.55448380e-02, -2.88164957e-01, -1.75702068e-01, -2.03681122e-01,
#        -1.44358267e-01,  8.44291267e-01,  5.49883507e-02, -7.07981008e-02,
#         7.52868185e-03, -4.64299449e-01,  6.74526515e-02, -1.01328688e-01,
#        -1.78625428e-02,  1.33560100e-01, -1.41250018e-01,  7.10640261e-02,
#        -2.28200492e-02, -1.75551171e-01, -6.26382150e-02,  5.61460304e-03,
#        -2.88558217e-01, -1.82683441e-01, -9.17746432e-02, -1.51904659e-02,
#         5.79875088e-01,  1.27741212e-02, -9.29480606e-02, -4.02004267e-02,
# ...

# %%
from sklearn.linear_model import LassoCV

# %%
lasso_cv_model = LassoCV(eps = 0.1, n_alphas = 100, cv = 5)

# %%
lasso_cv_model.fit(X_train, y_train)
# Out:
# LassoCV(cv=5, eps=0.1)

# %%
lasso_cv_model.alpha_
# Out:
# 8.297890384073522e+20

# %%
test_predictions = lasso_cv_model.predict(X_test)

# %%
MAE = mean_absolute_error(y_test, test_predictions)

# %%
RMSE = np.sqrt(mean_squared_error(y_test, test_predictions))

# %%
MAE
# Out:
# 3.957591278126473

# %%
RMSE
# Out:
# 4.664791512971867

# %%
lasso_cv_model.coef_
# Out:
# array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
# ...

# %%
from sklearn.linear_model import ElasticNetCV

# %%
elascit_model = ElasticNetCV(l1_ratio = [.1, .5, .7, .9, .95, .99, 1], 
                             eps = 0.001, n_alphas = 100, max_iter = 1000000)

# %%
elascit_model.fit(X_train, y_train)
# Out:
# ElasticNetCV(l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1], max_iter=1000000)

# %%
elascit_model.l1_ratio
# Out:
# [0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]

# %%
elascit_model.l1_ratio_ # It chooses l1 for just 10%
# Out:
# 0.1

# %%
elascit_model.alpha_
# Out:
# 1.1762045226223023e+20

# %%
test_predictions = elascit_model.predict(X_test)

# %%
MAE = mean_absolute_error(y_test, test_predictions)

# %%
MAE
# Out:
# 3.369667448582075

# %%
RMSE = np.sqrt(mean_squared_error(y_test, test_predictions))

# %%
RMSE
# Out:
# 4.1693422510837035

# %%
X = df.drop('sales', axis = 1)

# %%
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha = 100)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=100)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 7.34177578903413

# %%
model_two = Ridge(alpha = 1)

# %%
model_two.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred_two = model_two.predict(X_test)

# %%
mean_squared_error(y_test, y_pred_two)
# Out:
# 2.319021579428751

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
X_train, X_other, y_train, y_other = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# test_size = 0.5 (50% of 30% other --> test = 15% of all data)
X_eval, X_test, y_eval, y_test = train_test_split(X_other, y_other, test_size = 0.5, random_state = 101)

# %%
len(df)
# Out:
# 200

# %%
len(X_train)
# Out:
# 140

# %%
len(X_eval)
# Out:
# 30

# %%
len(X_test)
# Out:
# 30

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_eval = scaler.transform(X_eval)

# %%
model_one = Ridge(alpha = 100)

# %%
model_one.fit(X_train, y_train)
# Out:
# Ridge(alpha=100)

# %%
y_eval_pred = model.predict(X_eval)

# %%
mean_squared_error(y_eval, y_eval_pred)
# Out:
# 7.320101458823871

# %%
model_two = Ridge(alpha = 1)

# %%
model_two.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
new_pred_eval = model_two.predict(X_eval)

# %%
mean_squared_error(y_eval, new_pred_eval)
# Out:
# 2.3837830750569853

# %%
y_final_test_pred = model_two.predict(X_test)

# %%
mean_squared_error(y_test, y_final_test_pred)
# Out:
# 2.254260083800517

# %%
 df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X = df.drop('sales', axis = 1)

# %%
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
model = Ridge(alpha = 100)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model, X_train, y_train, scoring = 'neg_mean_squared_error', cv = 5)

# %%
scores
# Out:
# array([ -9.32552967,  -4.9449624 , -11.39665242,  -7.0242106 ,
#         -8.38562723])

# %%
abs(scores.mean()) # We can compare this value with another mean squared errors
# Out:
# 8.215396464543609

# %%
model = Ridge(alpha = 1)

# %%
scores = cross_val_score(model, X_train, y_train, scoring = 'neg_mean_squared_error', cv = 5)

# %%
abs(scores.mean())
# Out:
# 3.344839296530696

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final_test_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_final_test_pred)
# Out:
# 2.319021579428751

# %%
X = df.drop('sales', axis = 1)

# %%
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import cross_validate

# %%
model = Ridge(alpha = 100)

# %%
# https://scikit-learn.org/stable/modules/model_evaluation
scores = cross_validate(model, X_train, y_train, scoring = ['neg_mean_squared_error', 'neg_mean_absolute_error'], cv = 10)

# %%
scores
# Out:
# {'fit_time': array([0.0469389 , 0.00100994, 0.00129461, 0.00099897, 0.00140214,
#         0.00101638, 0.00100636, 0.00104976, 0.00107884, 0.00100684]),
#  'score_time': array([0.00153446, 0.00100398, 0.0010078 , 0.00122786, 0.        ,
#         0.00100493, 0.        , 0.00101113, 0.00120854, 0.        ]),
#  'test_neg_mean_squared_error': array([ -4.5127497 ,  -9.97653208,  -2.23342867,  -7.42924943,
#          -9.26109187,  -5.22660759,  -8.93123924,  -6.59165015,
#         -13.85044324,  -2.82952762]),
#  'test_neg_mean_absolute_error': array([-1.64234473, -2.48281433, -1.24658338, -2.35655124, -2.26924475,
#         -1.98028946, -2.47887835, -2.0540869 , -2.55080073, -1.27679154])}

# %%
scores = pd.DataFrame(scores)

# %%
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.046939    0.001534                    -4.512750
# 1  0.001010    0.001004                    -9.976532
# 2  0.001295    0.001008                    -2.233429
# 3  0.000999    0.001228                    -7.429249
# 4  0.001402    0.000000                    -9.261092
# 5  0.001016    0.001005                    -5.226608
# 6  0.001006    0.000000                    -8.931239
# 7  0.001050    0.001011                    -6.591650
# 8  0.001079    0.001209                   -13.850443
# 9  0.001007    0.000000                    -2.829528
#
#    test_neg_mean_absolute_error
# 0                     -1.642345
# 1                     -2.482814
# 2                     -1.246583
# 3                     -2.356551
# 4                     -2.269245
# 5                     -1.980289
# 6                     -2.478878
# 7                     -2.054087
# 8                     -2.550801
# 9                     -1.276792

# %%
scores.mean()
# Out:
# fit_time                        0.005680
# score_time                      0.000800
# test_neg_mean_squared_error    -7.084252
# test_neg_mean_absolute_error   -2.033839
# dtype: float64

# %%
model = Ridge(alpha = 1)

# %%
# https://scikit-learn.org/stable/modules/model_evaluation
scores = cross_validate(model, X_train, y_train, scoring = ['neg_mean_squared_error', 'neg_mean_absolute_error'], cv = 10)

# %%
scores = pd.DataFrame(scores)

# %%
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.001522    0.000000                    -1.628513
# 1  0.001001    0.000000                    -2.570641
# 2  0.001000    0.000000                    -1.025206
# 3  0.001505    0.001006                    -1.631940
# 4  0.000999    0.000000                    -2.777650
# 5  0.000000    0.001000                    -2.549585
# 6  0.001002    0.000000                    -2.333451
# 7  0.001927    0.000000                    -1.901408
# 8  0.001005    0.000999                    -8.977929
# 9  0.001004    0.000000                    -1.739917
#
#    test_neg_mean_absolute_error
# 0                     -0.993484
# 1                     -1.214107
# 2                     -0.861855
# 3                     -0.991249
# 4                     -1.384763
# 5                     -1.202138
# 6                     -1.281489
# 7                     -1.251296
# 8                     -1.733063
# 9                     -0.946307

# %%
scores.mean()
# Out:
# fit_time                        0.001097
# score_time                      0.000301
# test_neg_mean_squared_error    -2.713624
# test_neg_mean_absolute_error   -1.185975
# dtype: float64

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_final_pred)
# Out:
# 3.7310152520189774

# %%
X = df.drop('sales', axis = 1)

# %%
y = df['sales']

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train
# Out:
#         TV  radio  newspaper
# 85   193.2   18.4       65.7
# 183  287.6   43.0       71.8
# 127   80.2    0.0        9.2
# 53   182.6   46.2       58.7
# 100  222.4    4.3       49.8
# ..     ...    ...        ...
# 63   102.7   29.6        8.4
# 70   199.1   30.6       38.7
# 81   239.8    4.1       36.9
# 11   214.7   24.0        4.0
# 95   163.3   31.6       52.9
#
# [140 rows x 3 columns]

# %%
X_test
# Out:
#         TV  radio  newspaper
# 37    74.7   49.4       45.7
# 109  255.4   26.9        5.5
# 31   112.9   17.4       38.6
# 89   109.8   47.8       51.4
# 66    31.5   24.6        2.2
# 119   19.4   16.0       22.3
# 54   262.7   28.8       15.9
# 74   213.4   24.6       13.1
# 145  140.3    1.9        9.0
# 142  220.5   33.2       37.9
# 148   38.0   40.3       11.9
# 112  175.7   15.4        2.4
# 174  222.4    3.4       13.1
# 55   198.9   49.4       60.0
# 141  193.7   35.4       75.6
# 149   44.7   25.8       20.6
# 25   262.9    3.5       19.5
# 34    95.7    1.4        7.4
# 170   50.0   11.6       18.4
# 39   228.0   37.7       32.0
# 172   19.6   20.1       17.0
# 153  171.3   39.7       37.7
# 175  276.9   48.9       41.8
# 61   261.3   42.7       54.7
# 65    69.0    9.3        0.9
# 50   199.8    3.1       34.6
# 42   293.6   27.7        1.8
# 129   59.6   12.0       43.1
# 179  165.6   10.0       17.6
# 2     17.2   45.9       69.3
# 12    23.8   35.1       65.9
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_train
# Out:
# array([[ 4.93001715e-01, -3.39942376e-01,  1.61586707e+00],
#        [ 1.61337153e+00,  1.32852213e+00,  1.90079242e+00],
#        [-8.48118933e-01, -1.58789957e+00, -1.02319564e+00],
#        [ 3.67197477e-01,  1.54555816e+00,  1.28890355e+00],
#        [ 8.39556785e-01, -1.29625740e+00,  8.73192784e-01],
#        [ 1.17780403e+00,  8.87667686e-01,  1.92414696e+00],
#        [ 4.28912763e-01, -1.56818223e-01, -1.00918292e+00],
#        [-8.71855582e-01,  1.58625242e+00,  1.58543944e-01],
#        [-3.08110177e-01,  9.14797190e-01,  2.24643957e+00],
#        [-2.44021225e-01,  1.31495738e+00, -1.03026873e-01],
#        [ 9.83163509e-01, -1.35729878e+00,  2.50801039e+00],
#        [-1.06056194e+00, -7.33320185e-01, -5.98143063e-01],
#        [ 1.59438221e+00, -6.45149297e-01, -1.28009555e+00],
#        [-8.93218565e-01, -1.53364056e+00, -7.61624823e-01],
#        [-6.42796922e-01, -1.07243899e+00, -1.11661379e+00],
#        [ 7.68346839e-01,  1.24035124e+00,  3.96760224e-01],
# ...

# %%
X_test
# Out:
#         TV  radio  newspaper
# 37    74.7   49.4       45.7
# 109  255.4   26.9        5.5
# 31   112.9   17.4       38.6
# 89   109.8   47.8       51.4
# 66    31.5   24.6        2.2
# 119   19.4   16.0       22.3
# 54   262.7   28.8       15.9
# 74   213.4   24.6       13.1
# 145  140.3    1.9        9.0
# 142  220.5   33.2       37.9
# 148   38.0   40.3       11.9
# 112  175.7   15.4        2.4
# 174  222.4    3.4       13.1
# 55   198.9   49.4       60.0
# 141  193.7   35.4       75.6
# 149   44.7   25.8       20.6
# 25   262.9    3.5       19.5
# 34    95.7    1.4        7.4
# 170   50.0   11.6       18.4
# 39   228.0   37.7       32.0
# 172   19.6   20.1       17.0
# 153  171.3   39.7       37.7
# 175  276.9   48.9       41.8
# 61   261.3   42.7       54.7
# 65    69.0    9.3        0.9
# 50   199.8    3.1       34.6
# 42   293.6   27.7        1.8
# 129   59.6   12.0       43.1
# 179  165.6   10.0       17.6
# 2     17.2   45.9       69.3
# 12    23.8   35.1       65.9
# ...

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.91339472,  1.76259419,  0.68168558],
#        [ 1.23121149,  0.23655959, -1.19601922],
#        [-0.46002473, -0.40776614,  0.35005115],
#        [-0.49681653,  1.65407618,  0.9479273 ],
#        [-1.42610633,  0.08056494, -1.35015916],
#        [-1.56971305, -0.5027194 , -0.41130676],
#        [ 1.31785025,  0.36542473, -0.71024484],
#        [ 0.73274187,  0.08056494, -0.84103025],
#        [-0.13483264, -1.45903442, -1.03253746],
#        [ 0.81700697,  0.66384928,  0.3173548 ],
#        [-1.34896222,  1.14539797, -0.89708114],
#        [ 0.28530604, -0.54341366, -1.34081735],
#        [ 0.83955678, -1.35729878, -0.84103025],
#        [ 0.56065116,  1.76259419,  1.34962534],
#        [ 0.49893588,  0.81306155,  2.07828691],
#        [-1.26944445,  0.16195345, -0.49071219],
#        [ 1.32022392, -1.3505164 , -0.54209217],
#        [-0.66415991, -1.4929463 , -1.10727197],
#        [-1.20654233, -0.80114395, -0.59347216],
#        [ 0.9060194 ,  0.9690562 ,  0.04177126],
# ...

# %%
from sklearn.linear_model import ElasticNet

# %%
base_elastic_net_model = ElasticNet()

# %%
param_grid = {'alpha' : [0.1, 1, 5, 10, 50, 100], 
              'l1_ratio' : [.1, .5, .7, .95, .99, 1]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_model = GridSearchCV(estimator = base_elastic_net_model,
                         param_grid = param_grid,
                         scoring = 'neg_mean_squared_error',
                         cv = 5, 
                         verbose = 2)

# %%
grid_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# ...

# %%
grid_model.best_estimator_
# Out:
# ElasticNet(alpha=0.1, l1_ratio=1)

# %%
grid_model.best_params_
# Out:
# {'alpha': 0.1, 'l1_ratio': 1}

# %%
pd.DataFrame(grid_model.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.000948  5.535326e-04         0.000200        0.000400         0.1
# 1        0.000738  6.233241e-04         0.000418        0.000512         0.1
# 2        0.000902  1.987023e-04         0.000200        0.000400         0.1
# 3        0.000802  4.010865e-04         0.000395        0.000572         0.1
# 4        0.000621  5.982372e-04         0.000260        0.000486         0.1
# 5        0.000252  5.044937e-04         0.000679        0.000573         0.1
# 6        0.000601  4.904557e-04         0.000603        0.000493           1
# 7        0.000418  5.128692e-04         0.000441        0.000542           1
# 8        0.000802  4.010543e-04         0.000399        0.000489           1
# 9        0.000468  4.525174e-04         0.000435        0.000594           1
# 10       0.000500  6.337735e-04         0.000201        0.000402           1
# ...

# %%
# If I am not satisfied with this result, I can change values for 'alpha' or values for 'l1_ratio'

# %%
y_pred = grid_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2.3873426420874737

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course\\Data\\Advertising.csv')

# %%
df.tail()
# Out:
#         TV  radio  newspaper  sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('sales', axis = 1)

# %%
X.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y = df['sales']

# %%
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train[:4]
# Out:
# array([[ 0.49300171, -0.33994238,  1.61586707],
#        [ 1.61337153,  1.32852213,  1.90079242],
#        [-0.84811893, -1.58789957, -1.02319564],
#        [ 0.36719748,  1.54555816,  1.28890355]])

# %%
X_test[:4]
# Out:
# array([[-0.91339472,  1.76259419,  0.68168558],
#        [ 1.23121149,  0.23655959, -1.19601922],
#        [-0.46002473, -0.40776614,  0.35005115],
#        [-0.49681653,  1.65407618,  0.9479273 ]])

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha = 100)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=100)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 2.709571144855608

# %%
y_pred
# Out:
# array([15.34908128, 17.05755308, 12.73784965, 16.18231062, 10.85075815,
#         9.87999576, 17.6105132 , 15.80786278, 11.32616781, 17.30158479,
#        12.8883864 , 13.64670913, 13.71636726, 18.83377117, 17.38617584,
#        11.59912699, 14.88899736, 10.07145317, 10.14692243, 17.90771073,
#        10.25837266, 16.71492563, 20.57087744, 19.66643199, 10.14020781,
#        13.40084066, 18.09910709, 10.80433113, 13.00876939, 13.79206361,
#        12.73015096, 17.42108555, 11.50183684, 10.10362749, 16.18778637,
#        10.45161746, 11.25953403, 10.42658319, 12.30681396, 11.82281519,
#        14.75707677, 11.58372535, 12.01609545, 10.90016204, 12.55896716,
#        11.62961585, 10.8495293 , 15.74187916, 14.09264772, 18.45114683,
#        13.43419788, 14.05075373, 16.0980788 , 12.07046074, 13.15048011,
#         8.75095421, 19.21013193, 12.92686996, 16.49277745, 14.83525505])

# %%
df.tail()
# Out:
#         TV  radio  newspaper  sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4

# %%
df = pd.read_csv('C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course\\Data\\Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9
