# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course'

# %%
df = pd.read_csv('C:\\Users\\jovan\\Desktop\\MachineLearning-Course\\MachineLearning-Course\\Data\\mouse_viral_study.csv')

# %%
df
# Out:
#      Med_1_mL  Med_2_mL  Virus Present
# 0    6.508231  8.582531              0
# 1    4.126116  3.073459              1
# 2    6.427870  6.369758              0
# 3    3.672953  4.905215              1
# 4    1.580321  2.440562              1
# ..        ...       ...            ...
# 395  2.884122  3.271748              1
# 396  7.290855  9.488672              0
# 397  7.895325  8.272529              0
# 398  2.690592  2.674979              1
# 399  7.587821  9.473968              0
#
# [400 rows x 3 columns]

# %%
sns.scatterplot(data = df, x = 'Med_1_mL', y = 'Med_2_mL', hue = 'Virus Present')

# HYPERPLANE (2d line)

x = np.linspace(0, 10, 100)
m = -1
b = 11
y = m*x + b

plt.plot(x, y, 'black')

# %%
from sklearn.svm import SVC

# %%
y = df['Virus Present']

# %%
X = df.drop('Virus Present', axis = 1)

# %%
model = SVC(kernel = 'linear', C = 1000) # C represents number of points allowed to be inside the margin, but inverted
                                         # Larger number of C = smaller amount of points

# %%
model.fit(X, y)
# Out:
# SVC(C=1000, kernel='linear')

# %%
from svm_margin_plot import plot_svm_boundary

# %%
plot_svm_boundary(model, X, y)
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel = 'linear', C = 0.05)
model.fit(X, y)
# Out:
# SVC(C=0.05, kernel='linear')

# %%
plot_svm_boundary(model, X, y)
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel = 'rbf', C = 1, gamma = 'scale')
model.fit(X, y)
plot_svm_boundary(model, X, y)
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel = 'sigmoid')
model.fit(X, y)
plot_svm_boundary(model, X, y)
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel = 'poly', C = 0.05, degree = 4)
model.fit(X, y)
plot_svm_boundary(model, X, y)
# Out:
# C:\Users\jovan\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
from sklearn.model_selection import GridSearchCV

# %%
svm = SVC()
param_grid = {'C' : [0.01, 0.1, 1], 'kernel' : ['linear', 'rbf']}

# %%
grid = GridSearchCV(estimator = svm, param_grid = param_grid)

# %%
grid.fit(X, y)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 1], 'kernel': ['linear', 'rbf']})

# %%
grid.best_params_
# Out:
# {'C': 0.01, 'kernel': 'linear'}

# %%
df.head()
# Out:
#    Med_1_mL  Med_2_mL  Virus Present
# 0  6.508231  8.582531              0
# 1  4.126116  3.073459              1
# 2  6.427870  6.369758              0
# 3  3.672953  4.905215              1
# 4  1.580321  2.440562              1

# %%
df.tail()
# Out:
#      Med_1_mL  Med_2_mL  Virus Present
# 395  2.884122  3.271748              1
# 396  7.290855  9.488672              0
# 397  7.895325  8.272529              0
# 398  2.690592  2.674979              1
# 399  7.587821  9.473968              0
